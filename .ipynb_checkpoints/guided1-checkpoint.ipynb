# %% [markdown]
# This a guided exercise in preparation for first assignment.

# %%
import pandas as pd 

gitCloudRepo='https://raw.githubusercontent.com/elenapopic542/guided1/main/'
fileName="export.csv"

DFcsv=pd.read_csv(gitCloudRepo + fileName)

DFcsv
# Out:
#                           name                       slug  value  \
# 0                       Monaco                     monaco   55.4
# 1                        Japan                      japan   48.6
# 2    Saint Pierre and Miquelon  saint-pierre-and-miquelon   48.5
# 3                      Germany                    germany   47.8
# 4                        Italy                      italy   46.5
# ..                         ...                        ...    ...
# 222                       Chad                       chad   16.1
# 223                       Mali                       mali   16.0
# 224                     Angola                     angola   15.9
# 225                     Uganda                     uganda   15.7
# 226                      Niger                      niger   14.8
#
#     date_of_information  ranking                   region
# 0                   NaN        1                   Europe
# 1                   NaN        2  East and Southeast Asia
# ...

# %%
DFcsv.head(10)
# Out:
#                         name                       slug  value  \
# 0                     Monaco                     monaco   55.4
# 1                      Japan                      japan   48.6
# 2  Saint Pierre and Miquelon  saint-pierre-and-miquelon   48.5
# 3                    Germany                    germany   47.8
# 4                      Italy                      italy   46.5
# 5                    Andorra                    andorra   46.2
# 6                  Hong Kong                  hong-kong   45.6
# 7           Saint Barthelemy           saint-barthelemy   45.6
# 8                     Greece                     greece   45.3
# 9                 San Marino                 san-marino   45.2
#
#   date_of_information  ranking                             region
# 0                 NaN        1                             Europe
# 1                 NaN        2            East and Southeast Asia
# 2                 NaN        3                      North America
# ...

# %%
gitCloudRepo='https://raw.githubusercontent.com/elenapopic542/guided1/main/'
fileName="export%20copy.csv"

DFcsv=pd.read_csv(gitCloudRepo + fileName)

DFcsv
# Out:
#                         name                   slug          value  \
# 0                      China                  china  1,410,539,758
# 1                      India                  india  1,389,637,446
# 2              United States          united-states    337,341,954
# 3                  Indonesia              indonesia    277,329,163
# 4                   Pakistan               pakistan    242,923,845
# ..                       ...                    ...            ...
# 232                  Tokelau                tokelau          1,647
# 233          Paracel Islands        paracel-islands          1,440
# 234  Holy See (Vatican City)  holy-see-vatican-city          1,000
# 235  Cocos (Keeling) Islands  cocos-keeling-islands            596
# 236         Pitcairn Islands       pitcairn-islands             50
#
#     date_of_information  ranking                   region
# 0             2022 est.        1  East and Southeast Asia
# ...

# %%
DFcsv.head(10)
# Out:
#             name           slug          value date_of_information  ranking  \
# 0          China          china  1,410,539,758           2022 est.        1
# 1          India          india  1,389,637,446           2022 est.        2
# 2  United States  united-states    337,341,954           2022 est.        3
# 3      Indonesia      indonesia    277,329,163           2022 est.        4
# 4       Pakistan       pakistan    242,923,845           2022 est.        5
# 5        Nigeria        nigeria    225,082,083           2022 est.        6
# 6         Brazil         brazil    217,240,060           2022 est.        7
# 7     Bangladesh     bangladesh    165,650,475           2022 est.        8
# 8         Russia         russia    142,021,981           2022 est.        9
# 9         Mexico         mexico    129,150,971           2022 est.       10
#
#                     region
# 0  East and Southeast Asia
# 1               South Asia
# 2            North America
# ...
